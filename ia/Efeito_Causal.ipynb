# %% [markdown]
# # Prepara o ambiente

# %% [markdown]
# Monta o drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Declara os caminhos onde estão os dados

# %%
P_DADOS = "/content/drive/MyDrive/PIBIC 2019-2021/Notebooks/Busca Causal/dados/"    # caminho para os dfs.csv

# %% [markdown]
# Importa as bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# # Carrega os datasets

# %%
dados_70p = pd.read_csv()
